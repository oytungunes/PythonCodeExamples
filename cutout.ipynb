# %% [markdown]
# <a href="https://colab.research.google.com/github/oytungunes/PythonCodeExamples/blob/main/cutout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Simple cut out augmentation using tensorflow, issue with assigning values to tensors
#
# Kod
# https://stackoverflow.com/questions/69798370/simple-cut-out-augmentation-using-tensorflow-issue-with-assigning-values-to-ten

# %%
pip install tensorflow-addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.1 MB 7.2 MB/s
# ...

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow_addons as tfa

patchsize=64
def random_cut_out(images, labels):
    return tfa.image.random_cutout(images, (patchsize, patchsize), constant_values = 1), labels

flowers = tf.keras.utils.get_file(
    'flower_photos',
    'https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz',
    untar=True)

img_gen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

ds = tf.data.Dataset.from_generator(
    lambda: img_gen.flow_from_directory(flowers, batch_size=32, shuffle=True),
    output_types=(tf.float32, tf.float32))

ds = ds.map(random_cut_out)
images, _ = next(iter(ds.take(1)))
image = images[0]

plt.imshow(image.numpy())
# Out:
# Found 3670 images belonging to 5 classes.

# %%
images, _ = next(iter(ds.take(1)))
image = images[1]

plt.imshow(image.numpy())
# Out:
# Found 3670 images belonging to 5 classes.

# %%
image = images[2]

plt.imshow(image.numpy())

# %% [markdown]
# ### PATCH SIZE ARTIYOR

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow_addons as tfa

patchsize=128
def random_cut_out(images, labels):
    return tfa.image.random_cutout(images, (patchsize, patchsize), constant_values = 1), labels

flowers = tf.keras.utils.get_file(
    'flower_photos',
    'https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz',
    untar=True)

img_gen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

ds = tf.data.Dataset.from_generator(
    lambda: img_gen.flow_from_directory(flowers, batch_size=32, shuffle=True),
    output_types=(tf.float32, tf.float32))

ds = ds.map(random_cut_out)
images, _ = next(iter(ds.take(1)))
image = images[0]

plt.imshow(image.numpy())
# Out:
# Found 3670 images belonging to 5 classes.

# %%
image = images[1]

plt.imshow(image.numpy())
